# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
auc_col = 'AUC'
ppi_col = 'PPI Network'
dt_db_col = 'Target DB'
method_col = 'Method'
lfc_cutoff_col = 'LFC Cutoff'
confidence_col = 'Confidence Cutoff'
dataset_col = 'Dataset'

# %%
geo_path = os.path.join('data', 'results.csv')

# %% [markdown]
# # Functions

# %% [markdown]
# First, let's define a function that will generate bar plots

# %%
def barplot(df, hue, color=None, palette=None):
    
    plt.xticks(rotation=90)
    plt.ylim(ymin=0, ymax=1.0)
    plt.legend(loc="lower right", bbox_to_anchor=(1,0))
    sns.barplot(data=df, hue=hue,  x='Dataset', y='AUC', color=color, palette=palette, 
                order=sorted(df['Dataset'].unique()), ax=ax)

# %% [markdown]
# # Project

# %% [markdown]
# Differential expression of five data sets from GEO using GEO2R and the proteins were ranked using the proposed GuiltyTargets approach.

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv(geo_path)

# %% [markdown]
# ## Method Comparison

# %% [markdown]
# First, we will evaluate the overall performance of GuiltyTargets

# %%
plt.rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [20, 15]
plt.gcf().subplots_adjust(bottom=0.40)
barplot(df, hue=method_col, palette='Oranges')

# %% [markdown]
# # Changing Inputs

# %% [markdown]
# The rest of this document will change the above columns one at a time to determine how much effect they have on the AUC values.

# %%
cmap = 'Blues'

# %% [markdown]
# ## Changing the PPI Network

# %% [markdown]
# This time we are investigating the effects of changing the PPI network, by comparing results using HIPPIE vs. using STRING.

# %%
barplot(df, ppi_col, palette=cmap, axes[0,0])

# %% [markdown]
# Here we see that the PPI network has an effect on how good the results turn out to be. STRING is better for all cases.
#
# However, we set the confidence threshold to 0, which means there was a lot of noise in our data. Let's see what happens when we set a confidence threshold in our PPI networks

# %%
barplot(df, confidence_col, palette=cmap)

# %% [markdown]
# # Changing the Target Database
#
# This part unfortunately will not give us any new information, because we cannot share TTD targets.

# %%
barplot(df, dt_db_col, palette=cmap)

# %% [markdown]
# # Changing the Differential Expression Definition

# %%
barplot(df, lfc_cutoff_col, palette=cmap)
